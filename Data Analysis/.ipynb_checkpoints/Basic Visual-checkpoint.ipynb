# %%
DATA_PATH = "C:/Users/rgoul/Desktop/genetic-fish-tank/FishTank/FishTank/bin/Debug/Data/2019-21-3--09-14-28"

import pandas as pd
import os

avg_fitness = pd.read_csv(os.path.join(DATA_PATH, "AverageFitness.csv"))
population = pd.read_csv(os.path.join(DATA_PATH, "Population.csv"))

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.plot(avg_fitness)
plt.plot(population)

# %%
plt.plot(avg_fitness)

# %%
plt.plot(population)
