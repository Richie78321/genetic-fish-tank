# %%
DATA_PATH = "C:/Users/rgoul/Desktop/genetic-fish-tank/FishTank/FishTank/bin/Debug/Data/2019-21-3--13-47-15"

import pandas as pd
import os

avg_fitness = pd.read_csv(os.path.join(DATA_PATH, "AverageFitness.csv"))
population = pd.read_csv(os.path.join(DATA_PATH, "Population.csv"))
avg_genetic_diversity = pd.read_csv(os.path.join(DATA_PATH, "AverageGeneticDiversity.csv"))

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.xlabel('Hundreds of Ticks')
plt.ylabel('Avg. Net Food Consumption')
plt.plot(avg_fitness)

# %%
plt.xlabel('Hundreds of Ticks')
plt.ylabel('Population')
plt.plot(population)

# %%
plt.xlabel('Hundres of Ticks')
plt.ylabel('Avg. SD of Genomes')
plt.plot(avg_genetic_diversity)
